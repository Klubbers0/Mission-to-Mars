# %%
from flask import Flask, render_template, redirect, url_for
from flask_pymongo import PyMongo
import scraping

# %%
app = Flask(__name__)

# %%
# Use flask_pymongo to set up mongo connection
app.config["MONGO_URI"] = "mongodb://localhost:27017/mars_app"
mongo = PyMongo(app)

# %%
@app.route("/")
def index():
   mars = mongo.db.mars.find_one()
   return render_template("index.html", mars=mars)

# %%
@app.route("/scrape")
def scrape():
   mars = mongo.db.mars
   mars_data = scraping.scrape_all()
   mars.update({}, mars_data, upsert=True)
   return redirect('/', code=302)

# %%
if __name__ == "__main__":
   app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2021-09-11 11:19:01,099] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-11-e191d5b2e6ba>", line 3, in index
#     mars = mongo.db.mars.find_one()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 1319, in find_one
#     for result in cursor.limit(-1):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1207, in next
#     if len(self.__data) or self._refresh():
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1100, in _refresh
#     self.__session = self.__collection.database.client._ensure_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:19:01] "GET / HTTP/1.1" 500 -
# [2021-09-11 11:28:52,563] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-11-e191d5b2e6ba>", line 3, in index
#     mars = mongo.db.mars.find_one()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 1319, in find_one
#     for result in cursor.limit(-1):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1207, in next
#     if len(self.__data) or self._refresh():
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1100, in _refresh
#     self.__session = self.__collection.database.client._ensure_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:28:52] "GET / HTTP/1.1" 500 -
# [2021-09-11 11:29:33,942] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-11-e191d5b2e6ba>", line 3, in index
#     mars = mongo.db.mars.find_one()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 1319, in find_one
#     for result in cursor.limit(-1):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1207, in next
#     if len(self.__data) or self._refresh():
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1100, in _refresh
#     self.__session = self.__collection.database.client._ensure_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:29:33] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [11/Sep/2021 11:29:34] "GET /favicon.ico HTTP/1.1" 404 -
# [2021-09-11 11:30:21,950] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-11-e191d5b2e6ba>", line 3, in index
#     mars = mongo.db.mars.find_one()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 1319, in find_one
#     for result in cursor.limit(-1):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1207, in next
#     if len(self.__data) or self._refresh():
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1100, in _refresh
#     self.__session = self.__collection.database.client._ensure_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:30:21] "GET / HTTP/1.1" 500 -
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Get LATEST driver version for 93.0.4577
# Trying to download new driver from https://chromedriver.storage.googleapis.com/93.0.4577.63/chromedriver_win32.zip
# [2021-09-11 11:35:02,102] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-11-e191d5b2e6ba>", line 3, in index
#     mars = mongo.db.mars.find_one()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 1319, in find_one
#     for result in cursor.limit(-1):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1207, in next
#     if len(self.__data) or self._refresh():
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1100, in _refresh
#     self.__session = self.__collection.database.client._ensure_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:35:02] "GET / HTTP/1.1" 500 -
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Get LATEST driver version for 93.0.4577
# Trying to download new driver from https://chromedriver.storage.googleapis.com/93.0.4577.63/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Katelyn\.wdm\drivers\chromedriver\win32\93.0.4577.63]
# [2021-09-11 11:36:31,497] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-11-e191d5b2e6ba>", line 3, in index
#     mars = mongo.db.mars.find_one()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 1319, in find_one
#     for result in cursor.limit(-1):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1207, in next
#     if len(self.__data) or self._refresh():
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py", line 1100, in _refresh
#     self.__session = self.__collection.database.client._ensure_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:36:31] "GET / HTTP/1.1" 500 -
# C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py:530: FutureWarning: browser.find_link_by_text is deprecated. Use browser.links.find_by_text instead.
#   FutureWarning,
# C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   """
# [2021-09-11 11:37:14,869] ERROR in app: Exception on /scrape [GET]
# Traceback (most recent call last):
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "<ipython-input-12-def9374392f4>", line 5, in scrape
#     mars.update({}, mars_data, upsert=True)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 3327, in update
#     write_concern, collation=collation)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py", line 870, in _update_retryable
#     _update, session)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1497, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1829, in _tmp_session
#     s = self._ensure_session(session)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1816, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1766, in __start_session
#     server_session = self._get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py", line 1802, in _get_server_session
#     return self._topology.get_server_session()
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 488, in get_server_session
#     None)
#   File "C:\Users\Katelyn\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py", line 217, in _select_servers_loop
#     (self._error_message(selector), timeout, self.description))
# pymongo.errors.ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 613cd6d103144946553171d4, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>
# 127.0.0.1 - - [11/Sep/2021 11:37:14] "GET /scrape HTTP/1.1" 500 -
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
